# %%
import cv2
import numpy as np
import glob
import os

#######################################
### Calibracion de imagen para eliminar distorsiones externas al sensor.
###     - Estimar la pose relativa cámara–plano de referencia.
###     - Rectificar y centrar las imágenes para que todas compartan la misma orientación y escala.
### Autor: Martinez Agustin
### Fecha: 16/10/2025
### Version: 1.0
#######################################


class CameraProcessor:
    def __init__(self, outpath = 'images'):
        # Variables Calibracion
        self._mtx = []
        self._dist = []
        self._image_res = []

        # Path de saldia de imágenes
        self._outpath = outpath

        # Variables ArUco
        self._center_coord = []
        self._homografy = None
        aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_100)
        parameters = cv2.aruco.DetectorParameters()
        self._aruco_detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

    def isCalibred(self):
        '''
        Indica si el objeto está calibrado o no.
        bool: True si esta calibrado, False sino.
        '''
        return (
            self._mtx is not None and self._dist is not None
            and hasattr(self._mtx, "shape") and self._mtx.size > 0
            and hasattr(self._dist, "shape") and self._dist.size > 0
        )

    def ImageFileName(self, img_path):
        '''
        Devuelve una lista con todas las imágenes dentro de una carpeta (jpg, png, jpeg).
        Parameters:
            img_path (str): path a la carpeta donde se encuentran las fotos.
        Returns:
            list: Lista de imágenes encontradas.
        '''
        img_fname = []

        self.checkPath(img_path)
        for ext in ('*.jpg', '*.png', '*.jpeg'):
            img_fname.extend(glob.glob(os.path.join(img_path, ext)))
        return img_fname
 
    def calib(self, calib_img_path, chess_dim = (9,6), chess_square_lenght = 30.0):
        '''
        Crea la matriz de distorsión de las fotos que se encuentren en el path indicado. Calibra al objeto cameraProcessor.
        Parameters:
            calib_img_path (str): path a la carpeta donde se encuentran todas las imágenes de calibración.
            chess_dim (tuple): dimensiones del tablero a ajedrez a detectar.
            chess_square_lenght (float): largo de un cuadrado del tablero de ajedrez en mm.
        Returns:
            Matlike: Matriz de la cámara.
            Matlike: Coeficientes de distorsión.
            list: Vector de rotación.
            list: Vector de traslación.
            list: Resolución de imágenes de calibración.
        '''
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
        corner_dim = (chess_dim[0]-1, chess_dim[1]-1)    #Las funciones utilizan las esquinas internas, no la cant de cuadrados

        objp = np.zeros((corner_dim[0]*corner_dim[1], 3), np.float32)
        objp[:,:2] = np.mgrid[0:corner_dim[0],0:corner_dim[1]].T.reshape(-1,2)
        objp *= chess_square_lenght     # Grilla con todas las posiciones de las esquinas

        objpoints = [] # puntos 3D en el mundo real
        imgpoints = [] # puntos 2D en la imagen

        # Lista de imagenes
        images = self.ImageFileName(calib_img_path)

        if not images:
            print("No hay imagenes.")
            return None
        if len(images) < 10:
            print("Advertencia. Pocas imágenes. Se recomiendan 10 o más en distintos ángulos")

        for fname in images:
            img = cv2.imread(fname)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)		# Lo pasa a escala de grises para mejorar
            ret, corners = cv2.findChessboardCornersSB(gray, corner_dim, None)
            
            if ret == True:
                print(f"Encontrado en {fname}")
                objpoints.append(objp)
                corners2 = cv2.cornerSubPix(gray,corners, (11,11), (-1,-1), criteria)
                imgpoints.append(corners2)

        if len(objpoints) == 0:
            print("No se detectaron esquinas en ninguna imagen.")
            return None

        # Resolucion utilizada para calibrar
        img = cv2.imread(images[0])                  # Nota = usa solo la primer imagen !!! 
        self._image_res = (img.shape[1], img.shape[0])    # calib_res = (WIDHT, HEIGHT) 

        # Calibración
        ret, self._mtx, self._dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
        
        return self._mtx, self._dist, rvecs, tvecs, self._image_res
    
    def saveCalibMatrix(self, file_name='calib_matrix.npz'):
        '''
        Guarda los valores de calibración en un archivo .npz
        Parameters:
            file_name (str): Nombre del archivo a guardar.
        '''
        out_path = os.path.join(self._outpath, file_name)
        self.checkPath(self._outpath)

        try:
            np.savez(out_path, mtx=self._mtx, dist=self._dist, _image_res=self._image_res )
            print(f"Matrices guardadas en {file_name}.npz")
        except Exception as e:
            print(f"Error al guardar: {e}")

    def loadCalibMatrix(self, file_name='calib_matrix.npz'):
        """
        Lee los valores de calibración de un archivo .npz.
        Parameters:
            file_name (str): Path completo o nombre del archivo a leer.
        Returns:
            Matlike: Matriz de la cámara.
            Matlike: Coeficientes de distorsión de la cámara.
            tuple: Resolución de imágenes de calibración.
        """
        if not os.path.exists(file_name):
            print(f"Archivo no encontrado: {file_name}")
            return None, None, None

        try:
            calib = np.load(file_name)
            self._mtx = calib["mtx"]
            self._dist = calib["dist"]
            self._image_res = tuple(calib["_image_res"])
            return self._mtx, self._dist, self._image_res
        except Exception as e:
            print(f"Error al cargar el archivo: {e}")
            return None, None, None

    def undistort(self, img):
        '''
        Elimina la distorsión intrínseca en una imagen.
        Parameters:
            img (Matlike): archivo del tipo Matlike de cv2.
        Returns:
            Matlike: Imagen sin distorción.
            Matlike: Matriz de cámara nueva.
            Matlike: Roi.
        '''
        if not self.checkImage(img):
            return None, None, None

        if (img.shape[1], img.shape[0]) != tuple(self._image_res):
            print("WARNING: Resolucion de imagen diferente a la de calibracion\n")

        try:
            h,  w = img.shape[:2]
            newcameramtx, roi = cv2.getOptimalNewCameraMatrix(self._mtx, self._dist, (w,h), 1, (w,h))

            # Elimina distorcion
            undistorted = cv2.undistort(img, self._mtx, self._dist, None, newcameramtx)
    
            # Recorte de la imagen
            x, y, w, h = roi
            undistorted = undistorted[y:y+h, x:x+w]
            return undistorted, newcameramtx, roi
        except Exception as e:
            print(f'Error al corregir distorcion {e}')
            return None, None, None
        
    def warp(self, img, corner_ids, plane_size, pixels_per_mm = 2):
        '''
        Realiza Homografía con 4 esquinas ArUco.
        Parameters:
            calib_value_file: Nombre de archivo (sin extensión) de las matrices de distorsión.
            images_path: path a carpeta de imágenes que van a realizar el path.
            corner_ids: IDs de ArUco a identificar como esquinas.
            plane_size: Tamaño del plano de 4 esquinas.
            pixels_per_mm: Resolución pixeles --> mm.
        '''
        if not self.isCalibred():
            print('No hay matriz intrinseca y/o coeficientes de distorsion')
            return None

        if not self.checkImage(img):
            print('No hay imagen')
            return None
        
        # Cálculo de puntos de esquinas (ejemplo: ([0 0], [0 100], [24 0], [24 100]) mm)
        image_size = (plane_size[0]*pixels_per_mm,
                    plane_size[1]*pixels_per_mm) 

        real_points = np.array([
                        [0, 0],                             # arriba izq
                        [image_size[0]-1, 0],               # arriba der
                        [image_size[0]-1, image_size[1]-1], # abajo der
                        [0, image_size[1]-1]                # abajo izq
                    ], dtype=np.float32)

       
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        corners, ids, _ = self._aruco_detector.detectMarkers(gray_img)
        corner_coords = self.get_corners(corner_ids, corners, ids)
        if corner_coords is None or len(corner_coords) != 4:
            print('no hay coordenadas')
            return None

        # Corrección de la imagen: 
        H, _ = cv2.findHomography(corner_coords, real_points)
        self._homografy = H
        aligned_img = cv2.warpPerspective(img, H, image_size)

        return aligned_img

    def get_corners(self, corner_ids, corners, ids):
        '''
        Devuelve un vector de 4 posiciones con los centros de cada esquina. 
        El resultado está ordenado [TOP LEFT, TOP RIGHT, BOTTOM RIGHT, BOTTOM LEFT]
        Parameters:
            corner_ids: Id's a utilizar como esquina.
            corners: Vectos de esquinas de todos los ArUco obtenidos.
            ids: Id de cada ArUco enviado en corners.
        '''
        detected_centers = []
        corner_coords = []

        if ids is not None:
            # Busqueda de corners:
            ids = ids.flatten()

            for i, marker_id in enumerate(ids):
                # Obtengo centros solo de los corners ID:
                if marker_id in corner_ids:
                    c = corners[i][0]
                    center = c.mean(axis=0)
                    detected_centers.append(center)

            if len(detected_centers) == 4:
                detected_centers = np.array(detected_centers, dtype=np.float32)

                s = detected_centers.sum(axis=1)
                diff = np.diff(detected_centers, axis=1)

                top_left = detected_centers[np.argmin(s)]
                bottom_right = detected_centers[np.argmax(s)]
                top_right = detected_centers[np.argmin(diff)]
                bottom_left = detected_centers[np.argmax(diff)]

                corner_coords = np.array([top_left, top_right, bottom_right, bottom_left], dtype=np.float32)

        return corner_coords

    def colorFilter(self, img, color_range):
        '''
        Detecta regiones de un color específico en todas las imágenes dentro de 'images_path/warped'
        y guarda los resultados en 'images_path/color'.

        Parameters:
            images_path (str): Carpeta base donde están las imágenes originales.
            color_range (tuple): (lower_HSV, upper_HSV) con los límites del color a detectar.
        '''

        if not self.checkImage(img):
            print("No hay imágenes.")
            return None, None

        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        mask = cv2.inRange(hsv, color_range[0], color_range[1])

        # Limpieza de ruido
        kernel = np.ones((5,5), np.uint8)
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
        mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

        # resultado a color
        # masked_img_color = cv2.bitwise_and(img, img, mask=mask)
        white_background = np.full_like(img, 255)  # fondo blanco
        masked_img_color = np.where(mask[..., None].astype(bool), img, white_background)

        return mask, masked_img_color

    def loadImage(self, img_path):
        '''
        Carga una imagen a partir de su path.
        Parameters:
            img_path: Path de la imagen.
        '''
        if self.checkPath(img_path, create=False):
            img = cv2.imread(img_path)
            return img
        else:
            return None
    
    def saveImage(self, img, file_name='img.jpeg', img_rel_path=''):
        '''
        Salva una imagen en la carpeta indicada.
        Parameters:
            img: Imagen a guardar.
            file_name: Nombre del archivo imagen a guardar.
            img_rel_path: Path relativo a donde se va a guardar.
        '''
        out_path = os.path.join(self._outpath, img_rel_path)
        self.checkPath(out_path)

        out_path = os.path.join(out_path, file_name)
        cv2.imwrite(out_path, img)

    def processImages(self, img_folder_path, color_filter, corner_ids, plane_size, pixels_per_mm = 2, center_id = 50, save = False, out_path='processed'):
        '''
        Realiza el proceso completo de una imagen. Requiere que la clase ya esté calibrada.
        Parameters:
            img_folder_path (str): Path a carpeta con fotos a procesar.
            color_filter (tuple): filtro de colores a utiliziar.
            corner_ids (list): Id de los ArUco que definen las esquinas.
            plane_size (tuple): Tamaño del plano en mm.
            pixels_per_mm (float): pixeles equivalentes a un mm en el resultado final.
            save (bool): Salva los resultados o no.
            out_path (str): Path donde guarda los resultados.
        returns:
            Matlike: Imagen procesada.
            Matlike: Imagen procesada a color.
        '''
        images = self.ImageFileName(img_folder_path)
        img_res = []
        img_color_res = []

        out = os.path.join(self._outpath, out_path)
        if save:
            self.checkPath(out)
        
        for fname in images:
            print(f'Procesando: {fname}\n')
            img = self.loadImage(fname)
            img, _, _ = self.undistort(img)
            
            self._center_coord = None
            self.getOrigin(img, center_id)

            img = self.warp(img, corner_ids, plane_size, pixels_per_mm)
            if self._center_coord is not None:
                self._center_coord = self.transformPoint(self._center_coord)

            # falta detectar centro!!
            if color_filter:
                img, img_color = self.colorFilter(img, color_filter)
            else:
                img_color = img

            img_color = self.drawOrigin(img_color)

            # Guardado
            if not self.checkImage(img):
                continue
            img_res.append(img)
            img_color_res.append(img_color)

            if save:
                name, ext = os.path.splitext(os.path.basename(fname))

                out_bw = os.path.join(out, f"{name}{ext}")
                out_color = os.path.join(out, f"{name}_color{ext}")
                cv2.imwrite(out_bw, img)
                cv2.imwrite(out_color, img_color)
        
        return img_res, img_color_res

    def transformPoint(self, points, inverse=False):
        '''
        Transforma uno o varios puntos utilizando la homografía almacenada en la clase.
        Parameters:
            points (tuple | list | np.ndarray): Punto o lista de puntos en formato (x, y).
            inverse (bool): Si True, aplica la homografía inversa (de plano a imagen original).
        Returns:
            np.ndarray: Puntos transformados en formato (N, 2).
        '''
        if self._homografy is None:
            print("No hay homografía almacenada. Ejecute warp primero.")
            return None

        pts = np.array(points, dtype=np.float32)

        # Forzar a formato (N, 1, 2)
        if pts.ndim == 1:  
            if pts.shape[0] != 2:
                raise ValueError("Un punto debe tener formato (x, y)")
            pts = pts.reshape((1, 1, 2))
        elif pts.ndim == 2:
            if pts.shape[1] != 2:
                raise ValueError("Cada punto debe tener formato (x, y)")
            pts = pts.reshape((-1, 1, 2))
        else:
            raise ValueError("Formato de puntos inválido. Esperado (N,2) o (2,)")

        # Seleccionar homografía directa o inversa
        H = np.linalg.inv(self._homografy) if inverse else self._homografy

        # Aplicar la transformación
        transformed = cv2.perspectiveTransform(pts, H)

        # Salida (N, 2)
        return transformed[:, 0, :]

    def getOrigin(self, img, origin_Id):
        '''
        Define al centro de coordenadas en el centro del ArUco con la ID correspondiente.
        Parameters:
            img: Imagen a analizar.
        origin_Id: Id del ArUco origen de coordenadas.
        '''
        if not self.checkImage(img):
            print("Imagen inválida para buscar origen.")
            return []
        corners, ids, _ = self._aruco_detector.detectMarkers(img)
        if ids is not None:
            for i, corner in enumerate(corners):
                if ids[i] == origin_Id:
                    c = corner[0]
                    self._center_coord = c.mean(axis=0)
                    break
        
        return self._center_coord
    
    def drawOrigin(self, img, radius=10, color=(0, 0, 255), thickness=-1):
        '''
        Dibuja un punto en la imagen en la posición del origen detectado.
        Parameters:
            img: Imagen donde se va a dibujar.
            radius (int): Radio del círculo.
            color (tuple): Color BGR (por defecto rojo).
            thickness (int): Grosor del círculo (-1 para relleno).
        '''
        if not self.checkImage(img):
            print("Imagen inválida para dibujar origen.")
            return img

        if self._center_coord is None or len(self._center_coord) == 0:
            print("No se detectó origen. Ejecute getOrigin primero.")
            return img
        
        coord = np.array(self._center_coord, dtype=np.float32).reshape(-1)
        x, y = int(coord[0]), int(coord[1])

        cv2.circle(img, (x, y), radius, color, thickness)
        return img

    def checkPath(self, path, create = True):
        '''
        Verifica que el Path exista. Lo crea sino.
        Parameters:
            path (str): Path a verificar.
            create (bool): Lo crea si no existe.
        '''
        exist = os.path.exists(path)
        if not exist and create:
            os.makedirs(path, exist_ok=True)
            exist = True
        return exist
    
    def checkImage(self, img):
        '''
        Verifica que la imagen exista y sea válida.

        Parameters:
            img (Matlike | None): Imagen a verificar.

        Returns:
            bool: True si la imagen es válida, False si no lo es.
        '''
        if img is None:
            return False

        if not isinstance(img, np.ndarray):
            return False

        if img.size == 0 or len(img.shape) < 2:
            return False

        return True
    
    def processDistances(self, img_folder_path, corner_ids, color_filter, plane_size, 
                        pixels_per_mm=1, center_id=50, angle_step=3):

        images = self.ImageFileName(img_folder_path)
        distances_out = []
        angles_out = []
        img_name = []

        for fname in images:
            print(f'Procesando (distancias): {fname}')
            img = self.loadImage(fname)
            img, _, _ = self.undistort(img)

            # Detectar origen
            self._center_coord = None
            self.getOrigin(img, center_id)
            if self._center_coord is None:
                print(f"[WARN] No se detectó centro en {fname}. Se omite.")
                continue

            # Warp (homografía)
            warped = self.warp(img, corner_ids, plane_size, pixels_per_mm)
            if warped is None:
                print(f"[WARN] Homografía falló en {fname}. Se omite.")
                continue

            # Convertir centro al plano rectificado
            center_t = self.transformPoint(self._center_coord)
            if center_t is None:
                print(f"[WARN] No se pudo transformar el centro. Se omite.")
                continue
            cx, cy = center_t[0]

            # Aplicar filtro de color
            mask, masked_img = self.colorFilter(warped, color_filter)
            # mask = 255 donde hay pared azul, 0 donde no

            if mask is None:
                print(f"[WARN] Filtro de color falló. Se omite.")
                continue
            h, w = mask.shape

            # Barrido
            angles = list(range(0, 180 + angle_step, angle_step))
            distances = []

            for angle_deg in angles:
                theta = np.deg2rad(angle_deg)
                dx = np.cos(theta)
                dy = np.sin(theta)

                dist = 0.0
                step = 1.0

                while True:
                    x = int(cx + dx * dist)
                    y = int(cy - dy * dist)

                    # salir de imagen
                    if x < 0 or x >= w or y < 0 or y >= h:
                        distances.append(dist/pixels_per_mm)
                        break

                    # detección de pared azul
                    if mask[y, x] > 0:
                        distances.append(dist/pixels_per_mm)
                        break

                    dist += step

            distances_out.append(distances)
            angles_out.append(angles)
            img_name.append(os.path.basename(fname))

        return distances_out, angles_out, img_name

# %%
import matplotlib.pyplot as plt

def plot_values(angles, y):
    """
    Grafica ángulo vs distancia en un polar, con:
      0° = derecha
      ángulos creciendo antihorario (como tu procesamiento)
    """

    angles_rad = np.deg2rad(angles)

    plt.figure(figsize=(8, 8))
    ax = plt.subplot(111, projection='polar')

    ax.plot(angles_rad, y, linewidth=2)

    # 0° hacia el +X (derecha)
    ax.set_theta_zero_location("E")

    # Ángulos creciendo ANTIHORARIO
    ax.set_theta_direction(1)

    ax.grid(True)
    plt.show()

# %% [markdown]
# # Prueba real

# %%
cam = CameraProcessor()
cam.calib('D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img')
cam.saveCalibMatrix('D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_matrix_celu_agus.npz')
# Out:
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122544(0).jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122544.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122545.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122546.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122547.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122549.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122550.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122552.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122554.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122555.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122557.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122558.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122559.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122601.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122602.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122603.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122604.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122606.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122607.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122609.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122612.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122616.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122621.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122625.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122626.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122627.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122628(0).jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122628.jpg
# Encontrado en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_img\20251206_122629.jpg
# Matrices guardadas en D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_matrix_celu_agus.npz.npz

# %%
color_filter = ((80, 120, 50), (160, 255, 255)) # Corresponde a AZUL
corner_ids = [15,15,15,15]
map_size = (680, 620)       # En mm
pixels_per_mm = 2           # Resolution


# Calibracion

# Hacer esto la primera vez con fotos de tu propia cámara.
# cam.calib('images/calib_img')
# cam.saveCalibMatrix('calib_matrix_agus')
cam = CameraProcessor()

cam.loadCalibMatrix('D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_matrix_celu_agus.npz')

# Esperar al usuario
# input("Presione ENTER para continuar con el procesamiento...")

# Procesado
cam.processImages('D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed', color_filter, corner_ids, map_size, pixels_per_mm, save=True);
# Out:
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\1.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\10.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\100.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\101.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\102.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\103.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\104.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\105.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\106.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\107.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\108.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\109.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\11.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\110.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\111.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\112.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\113.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\114.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\115.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\116.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\117.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\118.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\119.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\12.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\120.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\121.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\122.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\123.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\124.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\125.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\126.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\127.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\128.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\129.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\13.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\130.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\131.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\132.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\133.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\134.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\135.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\136.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\137.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\138.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\139.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\14.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\140.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\141.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\142.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\143.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\144.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\145.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\146.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\147.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\148.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\149.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\15.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\150.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\151.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\152.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\153.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\154.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\155.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\156.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\157.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\158.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\159.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\16.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\160.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\161.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\162.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\163.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\164.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\165.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\166.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\167.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\168.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\169.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\17.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\170.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\171.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\172.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\173.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\174.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\175.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\176.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\177.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\178.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\179.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\18.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\180.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\181.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\182.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\183.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\184.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\185.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\186.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\187.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\188.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\189.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\19.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\190.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\191.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\192.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\193.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\194.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\195.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\196.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\197.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\198.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\199.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\2.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\20.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\200.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\201.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\202.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\203.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\204.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\205.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\206.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\207.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\208.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\209.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\21.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\22.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\23.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\24.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\25.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\26.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\27.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\28.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\29.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\3.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\30.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\31.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\32.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\33.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\34.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\35.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\36.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\37.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\38.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\39.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\4.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\40.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\41.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\42.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\43.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\44.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\45.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\46.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\47.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\48.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\49.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\5.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\50.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\51.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\52.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\53.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\54.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\55.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\56.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\57.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\58.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\59.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\6.jpg
#
# no hay coordenadas
# No hay imágenes.
# Imagen inválida para dibujar origen.
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\60.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\61.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\62.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\63.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\64.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\65.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\66.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\67.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\68.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\69.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\7.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\70.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\71.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\72.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\73.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\74.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\75.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\76.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\77.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\78.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\79.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\8.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\80.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\81.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\82.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\83.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\84.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\85.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\86.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\87.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\88.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\89.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\9.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\90.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\91.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\92.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\93.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\94.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\95.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\96.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\97.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\98.jpg
#
# Procesando: D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed\99.jpg

# %%
color_filter = ((80, 120, 50), (160, 255, 255)) # Corresponde a AZUL
corner_ids = [15,15,15,15]
map_size = (680, 620)       # En mm
pixels_per_mm = 2           # Resolution

cam = CameraProcessor()
cam.loadCalibMatrix('D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/calib_matrix_celu_agus.npz')

distances, angles, img_names = cam.processDistances("D:/maste/Escritorio/Procesamiento de Imagen/Examples/images/data_renamed",
													corner_ids, color_filter, map_size, pixels_per_mm, angle_step=3)

# %%
img_num = 50

print(f"Imagen graficada {img_names[img_num]}")	
plot_values(angles[img_num], distances[img_num])
# Out:
# Imagen graficada 149.jpg

# %% [markdown]
# # Codigos random

# %% [markdown]
# ## Renombre de las imágenes

# %%
import os
import shutil
from datetime import datetime

def copiar_y_renombrar(origen, destino):
    os.makedirs(destino, exist_ok=True)

    EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tiff"}

    archivos = [
        f for f in os.listdir(origen)
        if os.path.splitext(f)[1].lower() in EXT
    ]

    if not archivos:
        print("No se encontraron imágenes.")
        return
    archivos_ordenados = sorted(archivos)

    for i, nombre in enumerate(archivos_ordenados, start=1):
        origen_path = os.path.join(origen, nombre)
        ext = os.path.splitext(nombre)[1]
        destino_path = os.path.join(destino, f"{i}{ext}")

        shutil.copy2(origen_path, destino_path)
        print(f"{nombre}  →  {i}{ext}")
    print("Renombre finalizado")

# Ejemplo de uso:
# copiar_y_renombrar("C:/fotos_originales", "C:/fotos_renombradas")

copiar_y_renombrar("D:\maste\Escritorio\Procesamiento de Imagen\Examples\images\data_raw", 
                   "D:\maste\Escritorio\Procesamiento de Imagen\Examples\images\data_renamed")

# %% [markdown]
# ## Fusión de csv con data de imágenes

# %%
import os
import json
import pandas as pd

def csv_merge(csv_dir, img_dir, out_dir, distances, angles, img_names):
    os.makedirs(out_dir, exist_ok=True)

    normalized_img_names = []
    for name in img_names:
        bn = os.path.basename(name).lower()
        normalized_img_names.append(bn)

    # Dictionary: {file_name}: num
    img_map = { normalized_img_names[i]: i for i in range(len(img_names)) }

    img_ids = set()
    for name in normalized_img_names:
        base, ext = os.path.splitext(name)
        if base.isdigit():
            img_ids.add(int(base))

    csv_files = sorted(
        [f for f in os.listdir(csv_dir) if f.endswith(".csv")],
        key=lambda x: int(x.replace(".csv", ""))
    )

    for csv_file in csv_files:
        csv_id = int(csv_file.replace(".csv", ""))
        in_path = os.path.join(csv_dir, csv_file)
        out_path = os.path.join(out_dir, csv_file)
        df = pd.read_csv(in_path)

        found_match = False
        for ext in [".jpeg", ".jpg", ".png"]:
            expected_img = f"{csv_id}{ext}"
            expected_img = expected_img.lower()

            if expected_img in img_map:
                idx = img_map[expected_img]
                df.loc[0, "angulos_mapa"] = json.dumps(angles[idx])
                df.loc[0, "distancias_mapa"] = json.dumps(distances[idx])
                df.loc[0, "image_path"] = os.path.join(img_dir, expected_img)
                print(f"[OK] {csv_file} + {expected_img} fusionado.")
                found_match = True
                break

        # No hay imagen --> agregar columnas vacías
        if not found_match:
            df.loc[0, "angulos_mapa"] = ""
            df.loc[0, "distancias_mapa"] = ""
            print(f"[WARN] {csv_file} sin imagen → columnas vacías.")

        df.to_csv(out_path, index=False)

    print("\nFUSIÓN COMPLETADA.")


csv_merge("D:\\maste\\Escritorio\\Medidor de sensores\\mediciones",
                  "D:\\maste\\Escritorio\\Procesamiento de Imagen\\Examples\\Dataset",
                  distances=distances, angles=angles, img_names=img_names)
# Out:
# [OK] 1.csv + 1.jpg fusionado.
# [OK] 2.csv + 2.jpg fusionado.
# [OK] 3.csv + 3.jpg fusionado.
# [OK] 4.csv + 4.jpg fusionado.
# [OK] 5.csv + 5.jpg fusionado.
# [WARN] 6.csv sin imagen → columnas vacías.
# [OK] 7.csv + 7.jpg fusionado.
# [OK] 8.csv + 8.jpg fusionado.
# [OK] 9.csv + 9.jpg fusionado.
# [OK] 10.csv + 10.jpg fusionado.
# [WARN] 11.csv sin imagen → columnas vacías.
# [OK] 12.csv + 12.jpg fusionado.
# [OK] 13.csv + 13.jpg fusionado.
# [OK] 14.csv + 14.jpg fusionado.
# [OK] 15.csv + 15.jpg fusionado.
# [WARN] 16.csv sin imagen → columnas vacías.
# [OK] 17.csv + 17.jpg fusionado.
# [OK] 18.csv + 18.jpg fusionado.
# [OK] 19.csv + 19.jpg fusionado.
# [OK] 20.csv + 20.jpg fusionado.
# [OK] 21.csv + 21.jpg fusionado.
# [OK] 22.csv + 22.jpg fusionado.
# [OK] 23.csv + 23.jpg fusionado.
# [OK] 24.csv + 24.jpg fusionado.
# [OK] 25.csv + 25.jpg fusionado.
# [OK] 26.csv + 26.jpg fusionado.
# [OK] 27.csv + 27.jpg fusionado.
# [OK] 28.csv + 28.jpg fusionado.
# [OK] 29.csv + 29.jpg fusionado.
# [OK] 30.csv + 30.jpg fusionado.
# [OK] 31.csv + 31.jpg fusionado.
# [OK] 32.csv + 32.jpg fusionado.
# [OK] 33.csv + 33.jpg fusionado.
# [OK] 34.csv + 34.jpg fusionado.
# [OK] 35.csv + 35.jpg fusionado.
# [OK] 36.csv + 36.jpg fusionado.
# [OK] 37.csv + 37.jpg fusionado.
# [OK] 38.csv + 38.jpg fusionado.
# [WARN] 39.csv sin imagen → columnas vacías.
# [OK] 40.csv + 40.jpg fusionado.
# [OK] 41.csv + 41.jpg fusionado.
# [OK] 42.csv + 42.jpg fusionado.
# [OK] 43.csv + 43.jpg fusionado.
# [OK] 44.csv + 44.jpg fusionado.
# [OK] 45.csv + 45.jpg fusionado.
# [WARN] 46.csv sin imagen → columnas vacías.
# [OK] 47.csv + 47.jpg fusionado.
# [OK] 48.csv + 48.jpg fusionado.
# [OK] 49.csv + 49.jpg fusionado.
# [OK] 50.csv + 50.jpg fusionado.
# [WARN] 51.csv sin imagen → columnas vacías.
# [OK] 52.csv + 52.jpg fusionado.
# [OK] 53.csv + 53.jpg fusionado.
# [OK] 54.csv + 54.jpg fusionado.
# [OK] 55.csv + 55.jpg fusionado.
# [OK] 56.csv + 56.jpg fusionado.
# [OK] 57.csv + 57.jpg fusionado.
# [OK] 58.csv + 58.jpg fusionado.
# [OK] 59.csv + 59.jpg fusionado.
# [OK] 60.csv + 60.jpg fusionado.
# [OK] 61.csv + 61.jpg fusionado.
# [OK] 62.csv + 62.jpg fusionado.
# [OK] 63.csv + 63.jpg fusionado.
# [OK] 64.csv + 64.jpg fusionado.
# [OK] 65.csv + 65.jpg fusionado.
# [OK] 66.csv + 66.jpg fusionado.
# [OK] 67.csv + 67.jpg fusionado.
# [OK] 68.csv + 68.jpg fusionado.
# [OK] 69.csv + 69.jpg fusionado.
# [OK] 70.csv + 70.jpg fusionado.
# [OK] 71.csv + 71.jpg fusionado.
# [OK] 72.csv + 72.jpg fusionado.
# [OK] 73.csv + 73.jpg fusionado.
# [OK] 74.csv + 74.jpg fusionado.
# [OK] 75.csv + 75.jpg fusionado.
# [OK] 76.csv + 76.jpg fusionado.
# [OK] 77.csv + 77.jpg fusionado.
# [OK] 78.csv + 78.jpg fusionado.
# [OK] 79.csv + 79.jpg fusionado.
# [OK] 80.csv + 80.jpg fusionado.
# [OK] 81.csv + 81.jpg fusionado.
# [OK] 82.csv + 82.jpg fusionado.
# [OK] 83.csv + 83.jpg fusionado.
# [OK] 84.csv + 84.jpg fusionado.
# [OK] 85.csv + 85.jpg fusionado.
# [OK] 86.csv + 86.jpg fusionado.
# [OK] 87.csv + 87.jpg fusionado.
# [OK] 88.csv + 88.jpg fusionado.
# [OK] 89.csv + 89.jpg fusionado.
# [OK] 90.csv + 90.jpg fusionado.
# [OK] 91.csv + 91.jpg fusionado.
# [OK] 92.csv + 92.jpg fusionado.
# [OK] 93.csv + 93.jpg fusionado.
# [OK] 94.csv + 94.jpg fusionado.
# [OK] 95.csv + 95.jpg fusionado.
# [OK] 96.csv + 96.jpg fusionado.
# [OK] 97.csv + 97.jpg fusionado.
# [OK] 98.csv + 98.jpg fusionado.
# [OK] 99.csv + 99.jpg fusionado.
# [OK] 100.csv + 100.jpg fusionado.
# [OK] 101.csv + 101.jpg fusionado.
# [OK] 102.csv + 102.jpg fusionado.
# [OK] 103.csv + 103.jpg fusionado.
# [OK] 104.csv + 104.jpg fusionado.
# [OK] 105.csv + 105.jpg fusionado.
# [OK] 106.csv + 106.jpg fusionado.
# [OK] 107.csv + 107.jpg fusionado.
# [OK] 108.csv + 108.jpg fusionado.
# [OK] 109.csv + 109.jpg fusionado.
# [OK] 110.csv + 110.jpg fusionado.
# [OK] 111.csv + 111.jpg fusionado.
# [OK] 112.csv + 112.jpg fusionado.
# [OK] 113.csv + 113.jpg fusionado.
# [OK] 114.csv + 114.jpg fusionado.
# [OK] 115.csv + 115.jpg fusionado.
# [OK] 116.csv + 116.jpg fusionado.
# [OK] 117.csv + 117.jpg fusionado.
# [OK] 118.csv + 118.jpg fusionado.
# [OK] 119.csv + 119.jpg fusionado.
# [OK] 120.csv + 120.jpg fusionado.
# [OK] 121.csv + 121.jpg fusionado.
# [OK] 122.csv + 122.jpg fusionado.
# [OK] 123.csv + 123.jpg fusionado.
# [OK] 124.csv + 124.jpg fusionado.
# [OK] 125.csv + 125.jpg fusionado.
# [OK] 126.csv + 126.jpg fusionado.
# [OK] 127.csv + 127.jpg fusionado.
# [OK] 128.csv + 128.jpg fusionado.
# [WARN] 129.csv sin imagen → columnas vacías.
# [OK] 130.csv + 130.jpg fusionado.
# [WARN] 131.csv sin imagen → columnas vacías.
# [OK] 132.csv + 132.jpg fusionado.
# [OK] 133.csv + 133.jpg fusionado.
# [OK] 134.csv + 134.jpg fusionado.
# [WARN] 135.csv sin imagen → columnas vacías.
# [OK] 136.csv + 136.jpg fusionado.
# [OK] 137.csv + 137.jpg fusionado.
# [OK] 138.csv + 138.jpg fusionado.
# [OK] 139.csv + 139.jpg fusionado.
# [OK] 140.csv + 140.jpg fusionado.
# [OK] 141.csv + 141.jpg fusionado.
# [OK] 142.csv + 142.jpg fusionado.
# [OK] 143.csv + 143.jpg fusionado.
# [OK] 144.csv + 144.jpg fusionado.
# [WARN] 145.csv sin imagen → columnas vacías.
# [OK] 146.csv + 146.jpg fusionado.
# [OK] 147.csv + 147.jpg fusionado.
# [OK] 148.csv + 148.jpg fusionado.
# [OK] 149.csv + 149.jpg fusionado.
# [OK] 150.csv + 150.jpg fusionado.
# [OK] 151.csv + 151.jpg fusionado.
# [OK] 152.csv + 152.jpg fusionado.
# [OK] 153.csv + 153.jpg fusionado.
# [OK] 154.csv + 154.jpg fusionado.
# [OK] 155.csv + 155.jpg fusionado.
# [OK] 156.csv + 156.jpg fusionado.
# [OK] 157.csv + 157.jpg fusionado.
# [OK] 158.csv + 158.jpg fusionado.
# [OK] 159.csv + 159.jpg fusionado.
# [OK] 160.csv + 160.jpg fusionado.
# [OK] 161.csv + 161.jpg fusionado.
# [OK] 162.csv + 162.jpg fusionado.
# [OK] 163.csv + 163.jpg fusionado.
# [OK] 164.csv + 164.jpg fusionado.
# [OK] 165.csv + 165.jpg fusionado.
# [OK] 166.csv + 166.jpg fusionado.
# [OK] 167.csv + 167.jpg fusionado.
# [OK] 168.csv + 168.jpg fusionado.
# [OK] 169.csv + 169.jpg fusionado.
# [OK] 170.csv + 170.jpg fusionado.
# [OK] 171.csv + 171.jpg fusionado.
# [OK] 172.csv + 172.jpg fusionado.
# [OK] 173.csv + 173.jpg fusionado.
# [OK] 174.csv + 174.jpg fusionado.
# [OK] 175.csv + 175.jpg fusionado.
# [OK] 176.csv + 176.jpg fusionado.
# [OK] 177.csv + 177.jpg fusionado.
# [OK] 178.csv + 178.jpg fusionado.
# [OK] 179.csv + 179.jpg fusionado.
# [OK] 180.csv + 180.jpg fusionado.
# [OK] 181.csv + 181.jpg fusionado.
# [OK] 182.csv + 182.jpg fusionado.
# [OK] 183.csv + 183.jpg fusionado.
# [OK] 184.csv + 184.jpg fusionado.
# [OK] 185.csv + 185.jpg fusionado.
# [OK] 186.csv + 186.jpg fusionado.
# [OK] 187.csv + 187.jpg fusionado.
# [OK] 188.csv + 188.jpg fusionado.
# [OK] 189.csv + 189.jpg fusionado.
# [OK] 190.csv + 190.jpg fusionado.
# [OK] 191.csv + 191.jpg fusionado.
# [OK] 192.csv + 192.jpg fusionado.
# [OK] 193.csv + 193.jpg fusionado.
# [OK] 194.csv + 194.jpg fusionado.
# [OK] 195.csv + 195.jpg fusionado.
# [OK] 196.csv + 196.jpg fusionado.
# [OK] 197.csv + 197.jpg fusionado.
# [OK] 198.csv + 198.jpg fusionado.
# [OK] 199.csv + 199.jpg fusionado.
# [OK] 200.csv + 200.jpg fusionado.
# [OK] 201.csv + 201.jpg fusionado.
# [OK] 202.csv + 202.jpg fusionado.
# [OK] 203.csv + 203.jpg fusionado.
# [OK] 204.csv + 204.jpg fusionado.
# [OK] 205.csv + 205.jpg fusionado.
# [OK] 206.csv + 206.jpg fusionado.
# [OK] 207.csv + 207.jpg fusionado.
# [OK] 208.csv + 208.jpg fusionado.
# [OK] 209.csv + 209.jpg fusionado.
#
# FUSIÓN COMPLETADA.
