# %%
import os                           # Manejo de Directorios
import json                         # Manejo de vectores en el .csv
import pandas as pd                 # Manejo de Dataframes
import matplotlib.pyplot as plt     # Gráficos
from PIL import Image, ImageOps     # Gráficos de Imágenes
import numpy as np                  # Números en general

# Librerías para definir el modelo de IA
from keras.models import Model
from keras.layers import Conv1D, Dense, Flatten, Input, Add, Dropout, ReLU, BatchNormalization

# Librearías para definir el entrenamiento de la IA
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, History

from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import MeanAbsoluteError

# Librerías para Separación de Datos
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# Librería de Procesamiento de imágenes
import libs.CameraProcessor as cam

# Tipos de datos
from typing import Tuple
from matplotlib.axes import Axes
from matplotlib.figure import Figure

# %% [markdown]
# # Variables

# %%
# Path absoluto a direcciones de informacion
path_sensors_csv = "D:/maste/Escritorio/Proyecto - Machine Learning/Mediciones Sensores"
path_img_raw = "D:/maste/Escritorio/Proyecto - Machine Learning/Images/raw_img"

path_ds = "D:/maste/Escritorio/Proyecto - Machine Learning/Dataset"


# Variables para calibrar las imágenes. Pueden modificarse a gusto consumidor
color_filter = ((80, 120, 50), (160, 255, 255)) # Corresponde a AZUL
corner_ids = [15,15,15,15]
map_size = (680, 620)       # En mm
pixels_per_mm = 2           # Resolution
path_file_calib_matrix = "D:/maste/Escritorio/Proyecto - Machine Learning/calib_matrix_celu_agus.npz"

# Variables de entrenamiento de la IA
callbacks = [EarlyStopping(
            monitor="val_loss",
            patience=10,
            restore_best_weights=False
        ),
        ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=5,
            min_lr=1e-6
        ),
        ModelCheckpoint(
            filepath="mejor_modelo.keras",
            monitor="val_loss",
            save_best_only=True
        )
]

# %% [markdown]
# # Funciones

# %% [markdown]
# ### Funciones del dataframe
#
# Funciones utilizadas para limpiar la información original, crear los .CSV y cargar los .CSV al programa

# %%
def csv_merge(csv_dir, img_dir, out_dir, distances, angles, img_names):
    '''
    Añade a los .CSV del microcontrolador la información de su imagen asociada. Lo guarda todo en un CSV en out_dir
    '''
    os.makedirs(out_dir, exist_ok=True)

    normalized_img_names = []
    for name in img_names:
        bn = os.path.basename(name).lower()
        normalized_img_names.append(bn)

    # Dictionary: {file_name}: num
    img_map = { normalized_img_names[i]: i for i in range(len(img_names)) }

    img_ids = set()
    for name in normalized_img_names:
        base, ext = os.path.splitext(name)
        if base.isdigit():
            img_ids.add(int(base))

    csv_files = sorted(
        [f for f in os.listdir(csv_dir) if f.endswith(".csv")],
        key=lambda x: int(x.replace(".csv", ""))
    )

    for csv_file in csv_files:
        csv_id = int(csv_file.replace(".csv", ""))
        in_path = os.path.join(csv_dir, csv_file)
        out_path = os.path.join(out_dir, csv_file)
        df = pd.read_csv(in_path)

        found_match = False
        for ext in [".jpeg", ".jpg", ".png"]:
            expected_img = f"{csv_id}{ext}"
            expected_img = expected_img.lower()

            if expected_img in img_map:
                idx = img_map[expected_img]
                df.loc[0, "angulos_mapa"] = json.dumps(angles[idx])
                df.loc[0, "distancias_mapa"] = json.dumps(distances[idx])
                df.loc[0, "image_path"] = os.path.join(img_dir, expected_img)
                print(f"[OK] {csv_file} + {expected_img} fusionado.")
                found_match = True
                break

        # No hay imagen -> agregar columnas vacías
        if not found_match:
            df.loc[0, "angulos_mapa"] = ""
            df.loc[0, "distancias_mapa"] = ""
            print(f"[WARN] {csv_file} sin imagen -> columnas vacías.")

        df.to_csv(out_path, index=False)

    print("\nFUSIÓN COMPLETADA.")

def load_dataset(dataset_dir)->pd.DataFrame:
    """
    Carga todos los CSV del directorio dataset_dir.
    Retorna un DataFrame consolidado con columnas:
      id, fecha, imagen_path (si existe), angulo (lista),
      ultrasonico (lista), infrarrojo (lista), kalman (lista),
      distancias_mapa (lista, si existe), angulos_mapa (lista, si existe)
    """
    records = []
    for fname in os.listdir(dataset_dir):
        if not fname.lower().endswith(".csv"):
            continue
        path = os.path.join(dataset_dir, fname)
        df = pd.read_csv(path)

        row = df.iloc[0].to_dict()
        for col in ["angulo", "ultrasonico", "infrarrojo", "kalman", 
                    "distancias_mapa", "angulos_mapa"]:
            if col in row and pd.notna(row[col]) and row[col] != "":
                try:
                    row[col] = json.loads(row[col])
                except json.JSONDecodeError:
                    row[col] = None
            else:
                row[col] = None

        records.append(row)
    df = pd.DataFrame(records)
    
    df.set_index('id', inplace=True)

    return df

def plot_polar(angles_deg, values, title=None, ax:plt.Axes=None, 
               threshold=None, threshold_color="red", **plot_kwargs):
    if ax is None:
        fig = plt.figure(figsize=(6,6))
        ax = fig.add_subplot(111, projection="polar")
    else:
        fig = ax.figure

    angles_rad = np.deg2rad(angles_deg)
    ax.plot(angles_rad, values, **plot_kwargs)

    # Limite
    if threshold is not None:
        full_circle = np.linspace(0, 2*np.pi, 400)
        r_max = max(values.max(), threshold * 1.2)
        ax.fill_between(full_circle, threshold, r_max, color=threshold_color, alpha=0.2)
        ax.plot(full_circle, np.full_like(full_circle, threshold), color=threshold_color, linestyle="--", linewidth=1.5)

    ax.set_theta_zero_location("E")
    ax.set_theta_direction(1)

    if title:
        ax.set_title(title)

    ax.grid(True)
    return fig, ax

def plot_all_scans(df: pd.DataFrame, idx, mode="side"):
    """
    mode="side": 3 subplots polares, lado a lado
    mode="overlay": 3 curvas superpuestas en 1 solo polar
    """

    row = df.iloc[idx]
    ang = row["angulo"]
    us  = row["ultrasonico"]
    ir  = row["infrarrojo"]
    ang_map = row.get("angulos_mapa")
    dist_map = row.get("distancias_mapa")
    
    scan_id = row.get("id", idx)

    # --- MODO SUBPLOTS LATERALES ---
    if mode == "side":
        fig = plt.figure(figsize=(18,6))
        
        # Ultrasonido
        ax1 = fig.add_subplot(131, projection="polar")
        plot_polar(ang, us, title="Ultrasonido", ax=ax1)

        # Infrarrojo
        ax2 = fig.add_subplot(132, projection="polar")
        plot_polar(ang, ir, title="Infrarrojo", ax=ax2)

        # Imagen procesada
        ax3 = fig.add_subplot(133, projection="polar")
        plot_polar(ang_map, dist_map, title="Foto procesada", ax=ax3)

        fig.suptitle(f"Medición ID {scan_id}", fontsize=14)
        plt.tight_layout()
        plt.show()
        return fig

    # --- MODO SUPERPUESTO ---
    elif mode == "overlay":
        fig = plt.figure(figsize=(7,7))
        ax = fig.add_subplot(111, projection="polar")

        plot_polar(ang, us,  ax=ax, label="Ultrasonido")
        plot_polar(ang, ir,  ax=ax, label="Infrarrojo")
        plot_polar(ang_map, dist_map, ax=ax, label="Distancia mapa")

        ax.legend(loc="upper right", bbox_to_anchor=(1.2, 1.1))
        ax.set_title(f"Medición ID {scan_id} — Comparación")

        plt.show()
        return fig

    else:
        raise ValueError('mode debe ser "side" o "overlay"')

# %% [markdown]
# ### Funciones del Modelo
#
# Funciones para definir el modelo de IA a realizar y entrenar. También posee funciones para obtener de un dataframe las variables de entrada del modelo

# %%
def resnet_block(x, filters, kernel_size):
    shortcut = x

    # Conv 1
    x = Conv1D(filters, kernel_size, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Conv 2
    x = Conv1D(filters, kernel_size, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)

    # Proyección del shortcut si cambian los canales
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same", use_bias=False)(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # Suma residual + activación final
    x = Add()([x, shortcut])
    x = ReLU()(x)

    return x

def internal_block(x, filters, kernel_size):
    shortcut = x
    x = Conv1D(filters, kernel_size, padding="same", activation=None)(x)
    x = Conv1D(filters, kernel_size, padding="same", activation=None)(x)

    # Ajuste del shortcut si cambia el número de filtros
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D( filters, 1, padding="same", activation=None)(shortcut)
    x = Add()([x, shortcut])

    return x

def init_model(seq_len=61):
    inp = Input(shape=(seq_len, 2))

    #x = internal_block(inp, filters=32, kernel_size=5)   # Bloque 1
    #x = internal_block(x, filters=64, kernel_size=3)     # Bloque 2
    #x = internal_block(x, filters=64, kernel_size=3)     # Bloque 3
    x = resnet_block(inp, filters=32, kernel_size=5)   # Bloque 1
    x = resnet_block(x, filters=64, kernel_size=3)     # Bloque 2
    x = resnet_block(x, filters=64, kernel_size=3)     # Bloque 3

    x = Flatten()(x)
    x = Dense(128, activation="relu")(x)
    #x = Dropout(0.3)(x)
    out = Dense(seq_len, activation="linear")(x)

    model = Model(inp, out)
    model.compile(
        optimizer=Adam(1e-3),
        loss=MeanSquaredError(),
        metrics=[MeanAbsoluteError()]
    )

    return model

def get_data(df: pd.DataFrame) -> tuple[np.ndarray, np.ndarray]:
    X = []
    Y = []

    for _, row in df.iterrows():
        us = row['ultrasonico']        
        ir = row['infrarrojo']         
        real = row['distancias_mapa']  

        # Entrada (61,2)
        entrada = np.column_stack([us, ir])  
        X.append(entrada)
        Y.append(real)

    return np.array(X), np.array(Y)

def crossvalidate_model(X, Y, k=5, epochs=80, batch_size=16):       # No se utilizó. Folds muy pequeños, daba resultados muy malos
    kf = KFold(n_splits=k, shuffle=True)
    results = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        print(f"\n=== Fold {fold+1}/{k} ===")
        X_train, X_val = X[train_idx], X[val_idx]
        Y_train, Y_val = Y[train_idx], Y[val_idx]

        model = init_model(seq_len=X.shape[1])

        model.fit(
            X_train, Y_train,
            validation_data=(X_val, Y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks,
            verbose=0
        )

        loss_val, mae_val = model.evaluate(X_val, Y_val, verbose=0)
        print(f"Fold {fold+1} -> Loss: {loss_val:.4f}, MAE: {mae_val:.4f}")

        results.append((loss_val, mae_val))

    return np.array(results)

# %% [markdown]
# ### Funciones de métricas
#
# Creadas para poder comparar y visualizar resultados

# %%
def plot_history(history: History)->Tuple[Figure, Tuple[Axes, Axes]]:
    """
    Grafica el historial de entrenamiento de Keras en dos subplots:
    - Loss (train y val)
    - MAE (train y val, si existe)
    """

    fig, axes = plt.subplots(2, 1, figsize=(10, 10))
    ax_loss, ax_mae = axes

    # LOSS
    ax_loss.plot(history.history["loss"], label="Loss (train)")
    ax_loss.plot(history.history["val_loss"], label="Loss (val)")

    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Loss")
    ax_loss.set_title("Evolución del Loss")
    ax_loss.legend()
    ax_loss.grid(True)

    if "mean_absolute_error" in history.history:
        ax_mae.plot(history.history["mean_absolute_error"], label="MAE (train)")
        ax_mae.plot(history.history["val_mean_absolute_error"], label="MAE (val)")
        ax_mae.set_title("Evolución del MAE")
    else:
        ax_mae.text(0.5, 0.5, "MAE no disponible", ha='center', va='center')

    ax_mae.set_xlabel("Epoch")
    ax_mae.set_ylabel("MAE")
    ax_mae.legend()
    ax_mae.grid(True)

    plt.tight_layout()
    return fig, axes

def mae(y_true, y_pred):
    """Mean Absolute Error global para arrays (N, L)."""
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    """Mean Squared Error global."""
    return np.mean((y_true - y_pred)**2)

def rmse(y_true, y_pred):
    """Root Mean Squared Error global."""
    return np.sqrt(mse(y_true, y_pred))

def mape(y_true, y_pred):
    """Mean Absolute Percentage Error (ignora ceros en y_true)."""
    y_true = y_true.astype(float)
    mask = np.abs(y_true) > 1e-8
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

def metrics(y_true, y_pred):
    """Retorna todas las métricas en un diccionario."""
    return {
        "MAE": mae(y_true, y_pred),
        "MSE": mse(y_true, y_pred),
        "RMSE": rmse(y_true, y_pred),
        "MAPE(%)": mape(y_true, y_pred),
    }

# %% [markdown]
# # Carga del Dataset

# %% [markdown]
# ## Creacion del Dataset
#
# Se transforma la información original en un dataset unificado.
# La información original es:
# * Una carpeta con .csv con las mediciones del microcontrolador.
# * Una carpeta con la foto correspondiente de cada medición del microcontrolador.

# %%
## Cargo y calibro la cámara
#cam = cam.CameraProcessor()
#cam.loadCalibMatrix(path_file_calib_matrix)

## Corrijo las fotos
#distances, angles, img_names = cam.processDistances(path_img_raw, corner_ids, color_filter, map_size, pixels_per_mm, angle_step=3)

## Uno los resultados a los csv del microcontrolador
#csv_merge(path_sensors_csv, path_img_raw , path_ds, distances=distances, angles=angles, img_names=img_names)

# %% [markdown]
# ## Carga del Dataset en Python
#
# Se carga la carpeta con los .csv y se limpia el dataframe para poder ser utilizado luego.

# %%
# Cargo el dataframe
df = load_dataset(path_ds)

# Limpio el dataframe
df = df[
    (df["ultrasonico"].str.len() == 61) &
    (df["infrarrojo"].str.len() == 61) &
    (df["distancias_mapa"].str.len() == 61)
]
df.drop('imagen_path', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199 entries, 1 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            199 non-null    object
#  1   angulo           199 non-null    object
#  2   ultrasonico      199 non-null    object
#  3   infrarrojo       199 non-null    object
#  4   kalman           199 non-null    object
#  5   angulos_mapa     199 non-null    object
#  6   distancias_mapa  199 non-null    object
#  7   image_path       199 non-null    object
# dtypes: object(8)
# memory usage: 14.0+ KB

# %%
df
# Out:
#                           fecha  \
# id
# 1    2025-12-06T13:05:24.470944
# 10   2025-12-06T13:11:08.837964
# 100  2025-12-06T14:28:41.415743
# 101  2025-12-06T14:30:08.270929
# 102  2025-12-06T14:30:54.717360
# ..                          ...
# 95   2025-12-06T14:25:05.314638
# 96   2025-12-06T14:25:49.015872
# 97   2025-12-06T14:26:29.674281
# 98   2025-12-06T14:26:58.373174
# 99   2025-12-06T14:27:55.965120
#
#                                                 angulo  \
# id
# 1    [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 10   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 100  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 101  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 102  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# ..                                                 ...
# 95   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 96   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 97   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 98   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 99   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
#
#                                            ultrasonico  \
# id
# 1    [197.0, 192.0, 197.0, 197.0, 208.0, 212.0, 283...
# 10   [216.0, 216.0, 216.0, 216.0, 214.0, 214.0, 211...
# 100  [179.0, 179.0, 179.0, 179.0, 185.0, 185.0, 196...
# 101  [179.0, 179.0, 179.0, 179.0, 185.0, 185.0, 196...
# 102  [167.0, 167.0, 167.0, 172.0, 215.0, 211.0, 288...
# ..                                                 ...
# 95   [186.0, 186.0, 186.0, 186.0, 191.0, 191.0, 193...
# 96   [186.0, 186.0, 186.0, 186.0, 192.0, 187.0, 193...
# 97   [186.0, 186.0, 186.0, 186.0, 191.0, 187.0, 198...
# 98   [186.0, 186.0, 186.0, 186.0, 191.0, 191.0, 193...
# 99   [184.0, 179.0, 179.0, 179.0, 185.0, 185.0, 196...
#
#                                             infrarrojo  \
# id
# 1    [191.93, 191.93, 189.93, 184.93, 192.93, 201.9...
# 10   [208.93, 205.93, 208.93, 211.93, 211.93, 208.9...
# 100  [183.93, 183.93, 183.93, 181.93, 183.93, 185.9...
# 101  [183.93, 183.93, 183.93, 182.93, 183.93, 187.9...
# 102  [160.93, 161.93, 161.93, 160.93, 167.93, 174.9...
# ..                                                 ...
# 95   [188.93, 190.93, 189.93, 188.93, 192.93, 193.9...
# 96   [189.93, 190.93, 190.93, 190.93, 191.93, 193.9...
# 97   [190.93, 190.93, 190.93, 190.93, 191.93, 193.9...
# 98   [191.93, 190.93, 186.93, 189.93, 192.93, 191.9...
# 99   [183.93, 183.93, 183.93, 182.93, 185.93, 187.9...
#
#                                                 kalman  \
# id
# 1    [185.29212264150942, 188.86541630148992, 190.8...
# 10   [202.44306603773583, 207.00652059596845, 209.3...
# 100  [172.90533018867922, 177.48899211218227, 179.1...
# 101  [172.90533018867922, 177.48899211218227, 179.1...
# 102  [156.23080188679245, 160.64017528483785, 162.2...
# ..                                                 ...
# 95   [178.6223113207547, 183.8930236634531, 185.618...
# 96   [179.09872641509435, 184.1143207712533, 185.95...
# 97   [179.57514150943393, 184.33561787905344, 186.0...
# 98   [180.05155660377358, 184.55691498685363, 185.3...
# 99   [175.28740566037735, 178.59547765118316, 179.8...
#
#                                           angulos_mapa  \
# id
# 1    [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 10   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 100  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 101  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 102  [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# ..                                                 ...
# 95   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 96   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 97   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 98   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
# 99   [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 3...
#
#                                        distancias_mapa  \
# id
# 1    [309.0, 316.0, 323.0, 332.0, 341.0, 350.5, 356...
# 10   [320.0, 293.0, 292.5, 293.0, 295.0, 297.5, 301...
# 100  [254.5, 254.5, 256.5, 255.0, 257.0, 260.0, 262...
# 101  [259.0, 257.0, 257.5, 260.0, 260.5, 262.0, 265...
# 102  [251.5, 254.5, 257.0, 261.5, 266.0, 272.0, 279...
# ..                                                 ...
# 95   [266.5, 266.0, 267.5, 268.0, 269.0, 271.5, 275...
# 96   [264.5, 266.0, 264.0, 265.5, 267.5, 270.0, 273...
# 97   [263.0, 264.0, 261.5, 263.5, 265.5, 267.5, 271...
# 98   [281.0, 281.5, 280.5, 283.0, 284.0, 286.5, 290...
# 99   [257.5, 257.0, 258.5, 258.5, 259.5, 262.5, 265...
#
#                                             image_path
# id
# 1    D:/maste/Escritorio/Proyecto - Machine Learnin...
# 10   D:/maste/Escritorio/Proyecto - Machine Learnin...
# 100  D:/maste/Escritorio/Proyecto - Machine Learnin...
# 101  D:/maste/Escritorio/Proyecto - Machine Learnin...
# 102  D:/maste/Escritorio/Proyecto - Machine Learnin...
# ..                                                 ...
# 95   D:/maste/Escritorio/Proyecto - Machine Learnin...
# 96   D:/maste/Escritorio/Proyecto - Machine Learnin...
# 97   D:/maste/Escritorio/Proyecto - Machine Learnin...
# 98   D:/maste/Escritorio/Proyecto - Machine Learnin...
# 99   D:/maste/Escritorio/Proyecto - Machine Learnin...
#
# [199 rows x 8 columns]

# %%
idx = 83
plot_all_scans(df, idx, mode='overlay');

# %% [markdown]
# # Entrenamiento de IA

# %%
X, Y = get_data(df)
indices = df.index.to_numpy()

X_trainval, X_test, Y_trainval, Y_test, idx_trainval, idx_test = train_test_split(
    X, Y, indices,
    test_size=0.1,
    shuffle=True,
    random_state=21
)

# %% [markdown]
# ## CrossValidacion de Resultados

# %%
# cv_results = crossvalidate_model(X_trainval, Y_trainval, k=5)

# print("\n=== Resultados Cross-Validation ===")
# print("Loss promedio:", cv_results[:,0].mean())
# print("Loss std:     ", cv_results[:,0].std())
# print("MAE promedio:", cv_results[:,1].mean())
# print("MAE std:     ", cv_results[:,1].std())

# %% [markdown]
# ## Entrenamiento final

# %%
model_final = init_model(seq_len=X.shape[1])
model_final.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 61, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 61, 32)    │        320 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 61, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 61, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 61, 32)    │      5,120 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 61, 32)    │         64 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 32)    │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 32)    │        128 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 61, 32)    │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 61, 32)    │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 61, 64)    │      6,144 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 64)    │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 61, 64)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 61, 64)    │     12,288 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 61, 64)    │      2,048 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 64)    │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 64)    │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 61, 64)    │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 61, 64)    │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 61, 64)    │     12,288 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 64)    │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 61, 64)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 61, 64)    │     12,288 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 64)    │        256 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 61, 64)    │          0 │ batch_normalizat… │
# │                     │                   │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 61, 64)    │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3904)      │          0 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    499,840 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 61)        │      7,869 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 559,933 (2.14 MB)
#  Trainable params: 559,101 (2.13 MB)
#  Non-trainable params: 832 (3.25 KB)

# %%
history = model_final.fit(
    X_trainval,
    Y_trainval,
    validation_split=0.15,
    epochs=80,
    batch_size=16,
    callbacks=callbacks
)
# Out:
# Epoch 1/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 78213.6406 - mean_absolute_error: 267.7229 - val_loss: 33907.0547 - val_mean_absolute_error: 151.2758 - learning_rate: 0.0010
# Epoch 2/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 45283.7891 - mean_absolute_error: 191.2253 - val_loss: 62606.7578 - val_mean_absolute_error: 197.8683 - learning_rate: 0.0010
# Epoch 3/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 13812.1201 - mean_absolute_error: 93.3257 - val_loss: 23690.3359 - val_mean_absolute_error: 124.5756 - learning_rate: 0.0010
# Epoch 4/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5855.6357 - mean_absolute_error: 59.3505 - val_loss: 5538.0635 - val_mean_absolute_error: 53.9835 - learning_rate: 0.0010
# Epoch 5/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3954.1184 - mean_absolute_error: 47.1760 - val_loss: 6271.6865 - val_mean_absolute_error: 58.4564 - learning_rate: 0.0010
# Epoch 6/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3516.9214 - mean_absolute_error: 45.4035 - val_loss: 10537.3945 - val_mean_absolute_error: 86.5206 - learning_rate: 0.0010
# Epoch 7/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3092.1511 - mean_absolute_error: 41.5209 - val_loss: 10126.2861 - val_mean_absolute_error: 82.6790 - learning_rate: 0.0010
# Epoch 8/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2871.1863 - mean_absolute_error: 40.4046 - val_loss: 7365.2144 - val_mean_absolute_error: 65.9649 - learning_rate: 0.0010
# Epoch 9/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2725.2896 - mean_absolute_error: 38.9405 - val_loss: 6727.5068 - val_mean_absolute_error: 60.9393 - learning_rate: 0.0010
# Epoch 10/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2556.4087 - mean_absolute_error: 37.5082 - val_loss: 6442.6279 - val_mean_absolute_error: 58.5347 - learning_rate: 5.0000e-04
# Epoch 11/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2494.9475 - mean_absolute_error: 37.3966 - val_loss: 5759.0488 - val_mean_absolute_error: 55.2126 - learning_rate: 5.0000e-04
# Epoch 12/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2427.5801 - mean_absolute_error: 36.4363 - val_loss: 5770.7354 - val_mean_absolute_error: 55.0772 - learning_rate: 5.0000e-04
# Epoch 13/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2326.4316 - mean_absolute_error: 35.4818 - val_loss: 5096.8975 - val_mean_absolute_error: 51.9742 - learning_rate: 5.0000e-04
# Epoch 14/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2182.5181 - mean_absolute_error: 34.2479 - val_loss: 4643.3447 - val_mean_absolute_error: 49.4280 - learning_rate: 5.0000e-04
# Epoch 15/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2147.9590 - mean_absolute_error: 33.9334 - val_loss: 4174.4766 - val_mean_absolute_error: 47.0783 - learning_rate: 5.0000e-04
# Epoch 16/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2149.5251 - mean_absolute_error: 33.6252 - val_loss: 4321.0010 - val_mean_absolute_error: 47.3254 - learning_rate: 5.0000e-04
# Epoch 17/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2197.4243 - mean_absolute_error: 33.6851 - val_loss: 3694.6599 - val_mean_absolute_error: 43.9068 - learning_rate: 5.0000e-04
# Epoch 18/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2035.3195 - mean_absolute_error: 33.3384 - val_loss: 3517.2522 - val_mean_absolute_error: 43.2062 - learning_rate: 5.0000e-04
# Epoch 19/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2008.3425 - mean_absolute_error: 32.4463 - val_loss: 3256.4299 - val_mean_absolute_error: 40.9465 - learning_rate: 5.0000e-04
# Epoch 20/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1877.5604 - mean_absolute_error: 31.0868 - val_loss: 3225.0693 - val_mean_absolute_error: 39.9384 - learning_rate: 5.0000e-04
# Epoch 21/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1767.3308 - mean_absolute_error: 30.1363 - val_loss: 2928.6631 - val_mean_absolute_error: 38.1727 - learning_rate: 5.0000e-04
# Epoch 22/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1774.0132 - mean_absolute_error: 29.9936 - val_loss: 2841.0029 - val_mean_absolute_error: 37.1450 - learning_rate: 5.0000e-04
# Epoch 23/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1745.2827 - mean_absolute_error: 30.5759 - val_loss: 2650.6250 - val_mean_absolute_error: 36.1268 - learning_rate: 5.0000e-04
# Epoch 24/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1637.0520 - mean_absolute_error: 28.6430 - val_loss: 2482.2393 - val_mean_absolute_error: 34.5444 - learning_rate: 5.0000e-04
# Epoch 25/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1545.3959 - mean_absolute_error: 27.6095 - val_loss: 2479.6672 - val_mean_absolute_error: 34.0971 - learning_rate: 5.0000e-04
# Epoch 26/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1517.9432 - mean_absolute_error: 27.5339 - val_loss: 2234.4795 - val_mean_absolute_error: 32.3755 - learning_rate: 5.0000e-04
# Epoch 27/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1464.7343 - mean_absolute_error: 27.2599 - val_loss: 2204.0642 - val_mean_absolute_error: 32.2175 - learning_rate: 5.0000e-04
# Epoch 28/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1472.6813 - mean_absolute_error: 27.0506 - val_loss: 2106.0725 - val_mean_absolute_error: 31.2036 - learning_rate: 5.0000e-04
# Epoch 29/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1400.9359 - mean_absolute_error: 26.5784 - val_loss: 2009.9384 - val_mean_absolute_error: 30.4300 - learning_rate: 5.0000e-04
# Epoch 30/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1365.9948 - mean_absolute_error: 26.2644 - val_loss: 1973.6643 - val_mean_absolute_error: 30.0800 - learning_rate: 5.0000e-04
# Epoch 31/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1381.0997 - mean_absolute_error: 26.5448 - val_loss: 1944.1478 - val_mean_absolute_error: 29.8659 - learning_rate: 5.0000e-04
# Epoch 32/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1272.3247 - mean_absolute_error: 25.4626 - val_loss: 1793.7164 - val_mean_absolute_error: 28.4203 - learning_rate: 5.0000e-04
# Epoch 33/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1250.7523 - mean_absolute_error: 24.6547 - val_loss: 1953.2321 - val_mean_absolute_error: 29.5679 - learning_rate: 5.0000e-04
# Epoch 34/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1275.9861 - mean_absolute_error: 25.2437 - val_loss: 1691.7578 - val_mean_absolute_error: 27.9478 - learning_rate: 5.0000e-04
# Epoch 35/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1172.7306 - mean_absolute_error: 24.1885 - val_loss: 1788.3138 - val_mean_absolute_error: 28.5319 - learning_rate: 5.0000e-04
# Epoch 36/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1214.8038 - mean_absolute_error: 24.2037 - val_loss: 1584.3839 - val_mean_absolute_error: 26.7386 - learning_rate: 5.0000e-04
# Epoch 37/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1180.6534 - mean_absolute_error: 24.1616 - val_loss: 1727.3829 - val_mean_absolute_error: 28.4072 - learning_rate: 5.0000e-04
# Epoch 38/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1152.0929 - mean_absolute_error: 23.8053 - val_loss: 1597.0669 - val_mean_absolute_error: 27.0275 - learning_rate: 5.0000e-04
# Epoch 39/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1127.7866 - mean_absolute_error: 23.3850 - val_loss: 1475.4326 - val_mean_absolute_error: 25.5833 - learning_rate: 5.0000e-04
# Epoch 40/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1141.1779 - mean_absolute_error: 24.0807 - val_loss: 1500.1407 - val_mean_absolute_error: 26.8192 - learning_rate: 5.0000e-04
# Epoch 41/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1100.0583 - mean_absolute_error: 22.9609 - val_loss: 1373.0790 - val_mean_absolute_error: 25.2274 - learning_rate: 5.0000e-04
# Epoch 42/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1057.6802 - mean_absolute_error: 22.4894 - val_loss: 1385.1354 - val_mean_absolute_error: 26.0824 - learning_rate: 5.0000e-04
# Epoch 43/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1035.0621 - mean_absolute_error: 22.3314 - val_loss: 1328.6700 - val_mean_absolute_error: 25.6525 - learning_rate: 5.0000e-04
# Epoch 44/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 953.3024 - mean_absolute_error: 21.4460 - val_loss: 1334.5864 - val_mean_absolute_error: 24.5442 - learning_rate: 5.0000e-04
# Epoch 45/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 975.5622 - mean_absolute_error: 21.1995 - val_loss: 1325.1514 - val_mean_absolute_error: 24.7124 - learning_rate: 5.0000e-04
# Epoch 46/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1003.0512 - mean_absolute_error: 22.3040 - val_loss: 1366.0182 - val_mean_absolute_error: 26.6187 - learning_rate: 5.0000e-04
# Epoch 47/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 936.2045 - mean_absolute_error: 20.9143 - val_loss: 1253.1243 - val_mean_absolute_error: 24.4822 - learning_rate: 5.0000e-04
# Epoch 48/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 863.9393 - mean_absolute_error: 20.2283 - val_loss: 1348.4064 - val_mean_absolute_error: 26.0275 - learning_rate: 5.0000e-04
# Epoch 49/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 855.0540 - mean_absolute_error: 20.1092 - val_loss: 1237.6273 - val_mean_absolute_error: 24.1003 - learning_rate: 5.0000e-04
# Epoch 50/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 868.1859 - mean_absolute_error: 20.0831 - val_loss: 1221.1273 - val_mean_absolute_error: 23.8819 - learning_rate: 5.0000e-04
# Epoch 51/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 875.0452 - mean_absolute_error: 20.4190 - val_loss: 1284.3053 - val_mean_absolute_error: 24.3397 - learning_rate: 5.0000e-04
# Epoch 52/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 852.6667 - mean_absolute_error: 19.9582 - val_loss: 1169.5591 - val_mean_absolute_error: 23.3115 - learning_rate: 5.0000e-04
# Epoch 53/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 814.1057 - mean_absolute_error: 19.4938 - val_loss: 1203.8700 - val_mean_absolute_error: 23.1830 - learning_rate: 5.0000e-04
# Epoch 54/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 791.1298 - mean_absolute_error: 18.8957 - val_loss: 1147.5873 - val_mean_absolute_error: 23.0664 - learning_rate: 5.0000e-04
# Epoch 55/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 780.2108 - mean_absolute_error: 19.1118 - val_loss: 1259.0713 - val_mean_absolute_error: 24.0546 - learning_rate: 5.0000e-04
# Epoch 56/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 741.2921 - mean_absolute_error: 18.2421 - val_loss: 1094.7700 - val_mean_absolute_error: 21.8701 - learning_rate: 5.0000e-04
# Epoch 57/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 739.8338 - mean_absolute_error: 18.5941 - val_loss: 1328.6786 - val_mean_absolute_error: 24.8253 - learning_rate: 5.0000e-04
# Epoch 58/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 801.0209 - mean_absolute_error: 19.1861 - val_loss: 1054.2059 - val_mean_absolute_error: 21.6498 - learning_rate: 5.0000e-04
# Epoch 59/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 743.8973 - mean_absolute_error: 18.6456 - val_loss: 1130.2642 - val_mean_absolute_error: 22.5795 - learning_rate: 5.0000e-04
# Epoch 60/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 748.1655 - mean_absolute_error: 18.4174 - val_loss: 1130.6666 - val_mean_absolute_error: 22.2176 - learning_rate: 5.0000e-04
# Epoch 61/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 767.9842 - mean_absolute_error: 18.8443 - val_loss: 1369.0891 - val_mean_absolute_error: 25.3479 - learning_rate: 5.0000e-04
# Epoch 62/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 764.3588 - mean_absolute_error: 19.0536 - val_loss: 1103.6985 - val_mean_absolute_error: 21.3716 - learning_rate: 5.0000e-04
# Epoch 63/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 714.8204 - mean_absolute_error: 17.8587 - val_loss: 1110.1658 - val_mean_absolute_error: 22.3916 - learning_rate: 5.0000e-04
# Epoch 64/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 656.7975 - mean_absolute_error: 17.2499 - val_loss: 1032.7533 - val_mean_absolute_error: 21.2343 - learning_rate: 2.5000e-04
# Epoch 65/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 657.8023 - mean_absolute_error: 17.2686 - val_loss: 1113.1141 - val_mean_absolute_error: 22.0072 - learning_rate: 2.5000e-04
# Epoch 66/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 678.8992 - mean_absolute_error: 17.8052 - val_loss: 1029.0533 - val_mean_absolute_error: 20.5492 - learning_rate: 2.5000e-04
# Epoch 67/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 662.9860 - mean_absolute_error: 17.1614 - val_loss: 1092.0165 - val_mean_absolute_error: 21.5740 - learning_rate: 2.5000e-04
# Epoch 68/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 684.2265 - mean_absolute_error: 17.6680 - val_loss: 1002.0551 - val_mean_absolute_error: 20.5562 - learning_rate: 2.5000e-04
# Epoch 69/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 648.5903 - mean_absolute_error: 17.0750 - val_loss: 1213.7970 - val_mean_absolute_error: 23.0250 - learning_rate: 2.5000e-04
# Epoch 70/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 660.4792 - mean_absolute_error: 17.0419 - val_loss: 1019.8843 - val_mean_absolute_error: 20.5876 - learning_rate: 2.5000e-04
# Epoch 71/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 637.1702 - mean_absolute_error: 16.9910 - val_loss: 1045.9745 - val_mean_absolute_error: 20.9353 - learning_rate: 2.5000e-04
# Epoch 72/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 638.8616 - mean_absolute_error: 16.9977 - val_loss: 1118.0659 - val_mean_absolute_error: 21.9579 - learning_rate: 2.5000e-04
# Epoch 73/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 657.0176 - mean_absolute_error: 17.3721 - val_loss: 1136.1544 - val_mean_absolute_error: 21.9207 - learning_rate: 2.5000e-04
# Epoch 74/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 667.3731 - mean_absolute_error: 17.0691 - val_loss: 1086.3140 - val_mean_absolute_error: 21.5035 - learning_rate: 1.2500e-04
# Epoch 75/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 616.4764 - mean_absolute_error: 16.5959 - val_loss: 1106.0419 - val_mean_absolute_error: 21.7358 - learning_rate: 1.2500e-04
# Epoch 76/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 586.9026 - mean_absolute_error: 16.0773 - val_loss: 1050.2694 - val_mean_absolute_error: 20.9092 - learning_rate: 1.2500e-04
# Epoch 77/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 599.0676 - mean_absolute_error: 16.3360 - val_loss: 1025.7380 - val_mean_absolute_error: 20.7831 - learning_rate: 1.2500e-04
# Epoch 78/80
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 586.8229 - mean_absolute_error: 16.0163 - val_loss: 1102.8975 - val_mean_absolute_error: 21.5848 - learning_rate: 1.2500e-04

# %% [markdown]
# # Verificacion de resultados

# %%
fig, ax = plot_history(history)
ax[0].set_ylim(0, 10e3)
#ax[1].set_ylim(0, 10e3)
plt.show()

# %%
loss_test, mae_test = model_final.evaluate(X_test, Y_test, verbose=0)

print("\n=== RESULTADOS FINALES ===")
print(f'TRAIN Loss: {min(history.history['loss']):.4f}')
print(f'TRAIN MAE: {min(history.history['mean_absolute_error']):.4f}\n')
print(f'VAL Loss: {min(history.history['val_loss']):.4f}')
print(f'VAL MAE: {min(history.history['val_mean_absolute_error']):.4f}\n')
print(f"TEST Loss: {loss_test:.4f}")
print(f"TEST MAE:  {mae_test:.4f}\n")
# Out:
# === RESULTADOS FINALES ===
# TRAIN Loss: 586.8229
# TRAIN MAE: 16.0163
#
# VAL Loss: 1002.0551
# VAL MAE: 20.5492
#
# TEST Loss: 1278.0229
# TEST MAE:  23.1840

# %%
X, Y = get_data(df) 
kalman = np.stack(df['kalman'].to_list())
img_path = df['image_path'].to_numpy()
pred = model_final.predict(X)

_aux = metrics(Y, kalman)
print("Métricas Globales Kalman:")
print(f'MAE:\t\t{_aux['MAE']:.4f}\nMSE:\t\t{_aux['MSE']:.4f}\nRMSE:\t\t{_aux['RMSE']:.4f}\nMAPE(%):\t{_aux['MAPE(%)']:.4f}')

_aux = metrics(Y, pred) 
print("\nMétricas Globales IA:")
print(f'MAE:\t\t{_aux['MAE']:.4f}\nMSE:\t\t{_aux['MSE']:.4f}\nRMSE:\t\t{_aux['RMSE']:.4f}\nMAPE(%):\t{_aux['MAPE(%)']:.4f}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Métricas Globales Kalman:
# MAE:		66.2620
# MSE:		8272.0795
# RMSE:		90.9510
# MAPE(%):	22.1957
#
# Métricas Globales IA:
# MAE:		20.4347
# MSE:		883.5787
# RMSE:		29.7251
# MAPE(%):	6.8962

# %%
idx = np.random.randint(len(X))
us = X[idx][:, 0]
ir = X[idx][:, 1]

print(img_path[idx])

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection="polar")

angulos = np.linspace(0, 180, len(Y[idx]))
plot_polar(angulos, Y[idx], threshold=400, ax=ax, label="Real")
plot_polar(angulos, pred[idx], ax=ax, label="Predicho")
plot_polar(angulos, us, ax=ax, label="Ultrasonico")
plot_polar(angulos, ir, ax=ax, label="Infrarrojo")

[ymin, _] = ax.get_ylim()
ax.set_ylim(ymin, 410)

ax.legend(loc="upper right", bbox_to_anchor=(1.2, 1.1))
ax.set_title(f"Comparación Sensores (idx={idx})")
plt.show()
# Out:
# D:/maste/Escritorio/Proyecto - Machine Learning/Images/raw_img\180.jpg

# %%
fig = plt.figure(figsize=(12,10))

# Prediccion
ax_polar = fig.add_subplot(1, 2, 1, projection="polar")
plot_polar(angulos, Y[idx], threshold=400, ax=ax_polar, label="Real")
plot_polar(angulos, pred[idx], ax=ax_polar, label="Predicho")
plot_polar(angulos, kalman[idx], ax=ax_polar, label="Kalman")

[ymin, _] = ax_polar.get_ylim()
ax_polar.set_ylim(ymin, 410)
ax_polar.legend(loc="upper right", bbox_to_anchor=(1.2, 1.1))
ax_polar.set_title(f"Comparación con Kalman (idx={idx})")

# Imagen
ax_img = fig.add_subplot(1, 2, 2)
img = Image.open(img_path[idx])
img = ImageOps.exif_transpose(img)   # Corrige la rotación automáticamente
img = np.array(img)

ax_img.imshow(img)
ax_img.axis("off")


plt.tight_layout()
plt.show()

# %%
idx = np.random.randint(len(X_test))   
orig_idx = idx_test[idx]               

y_real = Y_test[idx]
y_pred = model_final.predict(X_test[idx:idx+1])[0]
y_kalman = df.loc[orig_idx, "kalman"]
img_path_test = df.loc[orig_idx, "image_path"]


angulos = np.linspace(0, 180, len(Y[idx]))

us = X_test[idx][:, 0]
ir = X_test[idx][:, 1]


## Prueba random de test
fig = plt.figure(figsize=(12,10))

# Prediccion
ax_polar = fig.add_subplot(1, 2, 1, projection="polar")
plot_polar(angulos, y_real, threshold=400, ax=ax_polar, label="Real")
plot_polar(angulos, y_pred, ax=ax_polar, label="Predicho")
plot_polar(angulos, y_kalman, ax=ax_polar, label="Kalman")

[ymin, _] = ax_polar.get_ylim()
ax_polar.set_ylim(ymin, 410)
ax_polar.legend(loc="upper right", bbox_to_anchor=(1.2, 1.1))
ax_polar.set_title(f"Comparación con Kalman (idx={idx})")

# Imagen
ax_img = fig.add_subplot(1, 2, 2)
img = Image.open(img_path_test)
img = ImageOps.exif_transpose(img)   # Corrige la rotación automáticamente
img = np.array(img)

ax_img.imshow(img)
ax_img.axis("off")


plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
